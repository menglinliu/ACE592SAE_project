# %%
import numpy as np
import matplotlib.pyplot as plt
import geopandas
import pyproj
import rasterio
import rasterstats
import pandas as pd
import json
import rasterio.mask
from rasterio.mask import mask
import rasterio.plot
from rasterio.plot import show
import matplotlib.colors as pltc
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib
import rasterio.warp
from rasterio.warp import calculate_default_transform, reproject, Resampling
from rasterstats import zonal_stats
from rasterio.merge import merge
import glob
import os
# %matplotlib inline

def getFeatures(gdf):
    """Function to parse features from GeoDataFrame in such a manner that rasterio wants them"""
    import json
    return [json.loads(gdf.to_json())['features'][0]['geometry']]

# %%
data_dir = "C:/Users/yoko1/Downloads/"

# %%
test = rasterio.open(data_dir + "./Hansen_GFC-2020-v1.8_lossyear_40N_080W.tif")

# %%
data_dir2 = "C:/Users/yoko1/Box/ACE 592 Project/zambia adm shp/"
zambia_file = data_dir2 + "ZMB_adm2.shp"
zambia = geopandas.read_file(zambia_file)

# %%
zambia.crs == test.crs
# Out:
# True

# %%
fig, ax = plt.subplots()
rasterio.plot.show(test, ax=ax)
#zambia.plot(ax=ax, facecolor='none', edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
zambia.plot(ax=ax, facecolor='none', edgecolor='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 1. Merge and mosaic raster files
# From https://automating-gis-processes.github.io/CSC/notebooks/L5/raster-mosaic.html

# %%
# File and folder paths
data_dir = "C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file/"
out_fp = os.path.join(data_dir, "zambia_treeloss.tif")

# Make a search criteria to select the DEM files
search_criteria = "Hansen_GFC-2019-v1.7_lossyear_*.tif"
q = os.path.join(data_dir, search_criteria)
print(q)
# Out:
# C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file/Hansen_GFC-2019-v1.7_lossyear_*.tif

# %%
# glob function can be used to list files from a directory with specific criteria
dem_fps = glob.glob(q)

# Files that were found:
dem_fps
# Out:
# ['C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file\\Hansen_GFC-2019-v1.7_lossyear_00N_020E.tif',
#  'C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file\\Hansen_GFC-2019-v1.7_lossyear_00N_030E.tif',
#  'C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file\\Hansen_GFC-2019-v1.7_lossyear_10S_020E.tif',
#  'C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file\\Hansen_GFC-2019-v1.7_lossyear_10S_030E.tif']

# %%
# List for the source files
src_files_to_mosaic = []

# Iterate over raster files and add them to source -list in 'read mode'
for fp in dem_fps:
    src = rasterio.open(fp)
    src_files_to_mosaic.append(src)

src_files_to_mosaic
# Out:
# [<open DatasetReader name='C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file/Hansen_GFC-2019-v1.7_lossyear_00N_020E.tif' mode='r'>,
#  <open DatasetReader name='C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file/Hansen_GFC-2019-v1.7_lossyear_00N_030E.tif' mode='r'>,
#  <open DatasetReader name='C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file/Hansen_GFC-2019-v1.7_lossyear_10S_020E.tif' mode='r'>,
#  <open DatasetReader name='C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file/Hansen_GFC-2019-v1.7_lossyear_10S_030E.tif' mode='r'>]

# %%
# Merge function returns a single mosaic array and the transformation info
mosaic, out_trans = merge(src_files_to_mosaic)

# Plot the result
show(mosaic, cmap='terrain')
# Out:
# <AxesSubplot:>

# %%
# Copy the metadata
out_meta = src.meta.copy()

# Update the metadata
out_meta.update({"driver": "GTiff",
                 "height": mosaic.shape[1],
                 "width": mosaic.shape[2],
                 "transform": out_trans,
                 "crs": "+proj=utm +zone=35 +ellps=GRS80 +units=m +no_defs "
                 }
                )

# %%
# Write the mosaic raster to disk
with rasterio.open(out_fp, "w", **out_meta) as dest:
    dest.write(mosaic)

# %% [markdown]
# https://cran.r-project.org/web/packages/exactextractr/vignettes/vig2_categorical.html

# %%
data_dir = "C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file/"

# %%
test = rasterio.open(data_dir + "zambia_treeloss.tif")

# %%
data_dir2 = "C:/Users/yoko1/Box/ACE 592 Project/zambia adm shp/"
zambia_file = data_dir2 + "ZMB_adm2.shp"
zambia = geopandas.read_file(zambia_file)

# %%
fig, ax = plt.subplots()
rasterio.plot.show(test, cmap='terrain', ax=ax)
zambia.plot(ax=ax, facecolor='none', edgecolor='white')
# Out:
# <AxesSubplot:>

# %%
import glob
import os
import fiona

data_dir = "C:/Users/yoko1/Box/ACE 592 Project/Deforestation data/raster file/"

with fiona.open("C:/Users/yoko1/Box/ACE 592 Project/zambia adm shp/zmb_admbnda_adm0_dmmu_20201124.shp", "r") as shapefile:
    shapes = [feature["geometry"] for feature in shapefile]

img_out, img_transform = mask(test,shapes,crop=True) 

img_out = img_out[:,:,:]

out_meta = test.meta.copy()
out_meta['height'] = img_out.shape[1]
out_meta['width'] = img_out.shape[2]
out_meta['transform'] = img_transform
        
out_meta['nodata'] = 0
        
with rasterio.open(data_dir+"./zambia_deforestation.tif", "w", **out_meta) as dest:
            dest.write(img_out)

# %%
deforestation = rasterio.open(data_dir + "zambia_deforestation.tif")

# %%
data_dir2 = "C:/Users/yoko1/Box/ACE 592 Project/zambia adm shp/"
zambia_file = data_dir2 + "ZMB_adm2.shp"

# %%
zambia = geopandas.read_file(zambia_file)

# %%
fig, ax = plt.subplots(figsize=(25, 15))
rasterio.plot.show(deforestation, cmap='terrain', ax=ax)
zambia.plot(ax=ax, facecolor='none', edgecolor='white')

fig.savefig("C:/Users/yoko1/Box/ACE 592 Project/figures/deforestation_map.png",dpi=300, bbox_inches = "tight")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 fig, ax = plt.subplots(figsize=(25, 15))
# ----> 2 rasterio.plot.show(deforestation, cmap='terrain', ax=ax)
#       3 zambia.plot(ax=ax, facecolor='none', edgecolor='white')
#       5 fig.savefig("C:/Users/yoko1/Box/ACE 592 Project/figures/deforestation_map.png",dpi=300, bbox_inches = "tight")
#
# File ~\anaconda3\envs\geo\lib\site-packages\rasterio\plot.py:91, in show(source, with_bounds, contour, contour_label_kws, ax, title, transform, adjust, **kwargs)
#      88     kwargs['extent'] = plotting_extent(source)
#      90 if source.count == 1:
# ---> 91     arr = source.read(1, masked=True)
#      92 else:
#      93     try:
#      94
#      95         # Lookup table for the color space in the source file. This will allow us to re-order it
#      96         # to RGB if needed
#
# File rasterio\_io.pyx:373, in rasterio._io.DatasetReaderBase.read()
#
# MemoryError: Unable to allocate 1.71 GiB for an array with shape (1, 39230, 46930) and data type uint8

# %% [markdown]
# ## Please disregard from here

# %%
zambia.crs == test.crs
# Out:
# False

# %%
zambia = zambia.to_crs(test.crs)

# %%
def getFeatures(gdf):
    """Function to parse features from GeoDataFrame in such a manner that rasterio wants them"""
    return [json.loads(gdf.to_json())['features'][0]['geometry']]

# %%
def clip_raster(raster,vector,filename):
    img_out, img_transform = mask(raster,getFeatures(vector))
    
    out_meta = raster.meta.copy()

    out_meta['height'] = img_out.shape[1]
    out_meta['width'] = img_out.shape[2]
    out_meta['transform'] = img_transform

    with rasterio.open("./"+filename+".tif", "w", **out_meta) as dest:
        dest.write(img_out)
    
    return rasterio.open("./"+filename+".tif")

# %%
zambia_deforestation = clip_raster(test,zambia,"zambia_deforestation")
# Out:
# C:\Users\yoko1\anaconda3\envs\geo\lib\site-packages\rasterio\mask.py:88: UserWarning: shapes are outside bounds of raster. Are they in different coordinate reference systems?
#   warnings.warn('shapes are outside bounds of raster. '

# %% [markdown]
# ## 2. Mapping from here

# %%
data_dir = "C:/Users/yoko1/Box/ACE592 - data sience/"
test = rasterio.open(data_dir + "zambia_deforestation.tif")

data_dir2 = "C:/Users/yoko1/Box/ACE 592 Project/zambia adm shp/"
zambia_file = data_dir2 + "ZMB_adm2.shp"
zambia = geopandas.read_file(zambia_file)

# %%
zambia.crs == test.crs
# Out:
# True

# %%
zambia = zambia.to_crs(test.crs)

# %%
fig, ax = plt.subplots()
rasterio.plot.show(test, ax=ax)
#zambia.plot(ax=ax, facecolor='none', edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
test = rasterio.open(data_dir + "./Hansen_GFC-2020-v1.8_lossyear_40N_080W.tif")
